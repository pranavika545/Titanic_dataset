# %% [markdown]
# ### Name: Pranavika Reddy Mavuluru
#
# ### StudentId: 202205560
#
# ### Email: x2022fis@stfx.ca
#
# ### Accuracy: 76.55%

# %%
# Importing modules
import numpy as np
import pandas as pd

# %%
# Importing dataset 
train_data = pd.read_csv("./train.csv")

# %%
# Importing important columns after analysis 
train_data = train_data[["Survived","Pclass","Sex","Age"]]

# %%
# Handle null value
train_data["Age"] = train_data["Age"].fillna(train_data["Age"].mean())
train_data = pd.get_dummies(train_data,columns=["Sex"])

# %%
train_data
# Out:
#      Survived  Pclass        Age  Sex_female  Sex_male
# 0           0       3  22.000000           0         1
# 1           1       1  38.000000           1         0
# 2           1       3  26.000000           1         0
# 3           1       1  35.000000           1         0
# 4           0       3  35.000000           0         1
# ..        ...     ...        ...         ...       ...
# 886         0       2  27.000000           0         1
# 887         1       1  19.000000           1         0
# 888         0       3  29.699118           1         0
# 889         1       1  26.000000           0         1
# 890         0       3  32.000000           0         1
#
# [891 rows x 5 columns]

# %%
# Collecting data for training
X = train_data[["Pclass","Sex_female","Sex_male","Age"]]
Y = train_data["Survived"]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    float64
#  3   Sex_female  891 non-null    uint8
#  4   Sex_male    891 non-null    uint8
# dtypes: float64(1), int64(2), uint8(2)
# memory usage: 22.7 KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    float64
#  3   Sex_female  891 non-null    uint8
#  4   Sex_male    891 non-null    uint8
# dtypes: float64(1), int64(2), uint8(2)
# memory usage: 22.7 KB

# %%
# Getting decision tree classifier
from sklearn.ensemble import RandomForestClassifier

tcf = RandomForestClassifier()
tcf.fit(X,Y)
# Out:
# RandomForestClassifier()

# %%
# Importing Test data
test_data = pd.read_csv("test.csv")

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test_data["Age"] = test_data["Age"].fillna(test_data["Age"].mean())
test_data = pd.get_dummies(test_data,columns=["Sex"])

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#           Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
# Transforming dataset
X_test = test_data[["Pclass","Sex_female","Sex_male","Age"]]

# %%
# Creating data frame for passender Id and survived 
out_values = pd.DataFrame(data={"PassengerId":test_data["PassengerId"],
                        "Survived":tcf.predict(X_test)})

# %%
# Creating sumbission file
out_values.to_csv("submission_3.csv",index=False)
